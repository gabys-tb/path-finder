# %%
import matplotlib.pyplot as plt

# %%
y = ['A-Star', 'UCS', 'BFS', 'Greedy']
s = [327.5, 327.5, 529, 642]

plt.plot(y, s, marker='o', color='orange')
plt.title('Método de busca x Custo da solução')
plt.savefig('g1.jpeg')

# %%
t = [0.4, 7.6, 14.9, 37.9]
yy = ['Greedy', 'A-Star', 'BFS', 'UCS']
plt.plot(yy, t, marker='o', color='purple')
plt.title('Método de busca x Tempo de execução')
plt.savefig('g2.jpeg')

# %%
ss =[609, 10351, 36560, 65724 ]
yy = ['Greedy', 'A-Star', 'BFS', 'UCS']
plt.plot(yy, ss, marker='o', color='green')
plt.title('Método de busca x Estados expandidos')
plt.savefig('g3.jpeg')
